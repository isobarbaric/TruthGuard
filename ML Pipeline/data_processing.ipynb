# %% [markdown]
# <h1>Data Processing</h1>
# <h3>
#     <ol>
#         <li>
#             Accessing Previously Extracted Data from Scraping
#         </li>
#         <li>
#             Combining Both Kinds of Articles and Converting The Combination to a DataFrame
#         </li>
#         <li>
#             Scraping to Obtain the Textual Content in all Short-listed Articles
#         </li>
#         <li>
#             Cleaning the Data Obtained to Ensure Only Textual Content is Taken
#         </li>
#         <li>
#             Saving the DataFrame for Short-listed Articles as JSON
#         </li>
#     </ol>
# </h3>
#
# ***

# %% [markdown]
# <h4>Accessing Previously Extracted Data from Scraping</h4>

# %%
import json

# creating a function to read in stored JSON files
def read_from_storage(filename: str) -> list:
    # specifying a filename where to create a new file
    filename = f"Data/extract/{filename}.json"

    # creating a new file located at filename and writing JSON-ified articles into that file
    with open(filename, 'r') as f:
        return json.loads(f.read())

# %% [markdown]
# <h4>Combining Both Kinds of Articles and Converting The Combination to a DataFrame</h4>

# %%
# reading the scientific and conspiracy articles stored in the data_acquisition process

science_articles = read_from_storage('science')
conspiracy_articles = read_from_storage('conspiracy')

# %%
# trimming the both sets of articles by the length of the minimum of the two

min_len = min(len(science_articles), len(conspiracy_articles))
science_articles = science_articles[:min_len]
conspiracy_articles = conspiracy_articles[:min_len]

# %%
import pandas as pd

# creating a pandas dataframe from the two lists for the two types of articles
df_science = pd.DataFrame.from_dict(science_articles)
df_conspiracy = pd.DataFrame.from_dict(conspiracy_articles)

# %%
# creating a new column to distinguish scientific articles from conspiracy ones

df_science['article_type'] = 1
df_conspiracy['article_type'] = 0

# %%
df_science
# Out:
#                                                  title  \
# 0    \n \n \n Quercetin for Seasonal Allergies?\n \...
# 1    \n \n \n How Many Times Should You Test for CO...
# 2    \n 08/08/2022\n Woman Pleads Guilty for Sellin...
# 3    \n 08/08/2022\n Seller of CBD Warned for COVID...
# 4    \n \n Product Reviews and Answers to Questions...
# ..                                                 ...
# 275  David Oliver: The overwhelming reaction to my ...
# 276               Investigating the monkeypox outbreak
# 277  Monkeypox: what we know about the 2022 outbrea...
# 278  Risk of preterm birth and stillbirth after cov...
# 279                                  COVID Information
#
#                                                   link  article_type
# 0    https://www.consumerlab.com/reviews/quercetin-...             1
# 1    https://www.consumerlab.com/answers/how-and-wh...             1
# 2    https://www.consumerlab.com/recalls/14684/woma...             1
# 3    https://www.consumerlab.com/recalls/14683/sell...             1
# 4       https://www.consumerlab.com/topic/coronavirus/             1
# ..                                                 ...           ...
# 275          https://www.bmj.com/content/378/bmj.o2017             1
# 276          https://www.bmj.com/content/377/bmj.o1314             1
# 277          https://www.bmj.com/content/378/bmj.o2058             1
# 278    https://www.bmj.com/content/378/bmj-2022-071416             1
# 279            https://www.sciencehistory.org/covid-19             1
#
# [280 rows x 3 columns]

# %%
df_conspiracy
# Out:
#                                                  title  \
# 0    Fauci to Step Down in December \xe2\x80\x94 Wi...
# 1    \n\t\t\t\t\t\t\t\t\t\tJudging the Covid-19 Pan...
# 2                   Is the COVID-19 Vaccine a Miracle?
# 3                        Is the COVID-19 vaccine safe?
# 4    A Christian Statement on Science for Pandemic ...
# ..                                                 ...
# 275  Most people infected with Omicron weren't even...
# 276     Zoonotic Langya virus found in China, CDC says
# 277  CDC quietly removes 'claim' that spike protein...
# 278  9/11 vs. COVID: The Sorry Tale of a Nation Gon...
# 279  9/11, JFK, COVID, Holocaust…Will Americans Be ...
#
#                                                   link  article_type
# 0    https://www.sgtreport.com/2022/08/fauci-to-ste...             0
# 1    https://americanfreepress.net/judging-the-covi...             0
# 2    https://biologos.org/post/is-the-covid-19-vacc...             0
# 3    https://biologos.org/resources/is-the-covid-19...             0
# 4    https://biologos.org/post/a-christian-statemen...             0
# ..                                                 ...           ...
# 275  https://www.sott.net/article/471164-Most-peopl...             0
# 276  https://www.sott.net/article/470863-Zoonotic-L...             0
# 277  https://www.sott.net/article/471150-CDC-quietl...             0
# 278  https://www.veteranstoday.com/2022/08/12/9-11-...             0
# 279  https://www.veteranstoday.com/2022/08/20/911-j...             0
#
# [280 rows x 3 columns]

# %%
# merging the two dataframes whilst also preserving order
df = pd.concat([df_science, df_conspiracy], axis=0, ignore_index=True)

# %%
df
# Out:
#                                                  title  \
# 0    \n \n \n Quercetin for Seasonal Allergies?\n \...
# 1    \n \n \n How Many Times Should You Test for CO...
# 2    \n 08/08/2022\n Woman Pleads Guilty for Sellin...
# 3    \n 08/08/2022\n Seller of CBD Warned for COVID...
# 4    \n \n Product Reviews and Answers to Questions...
# ..                                                 ...
# 555  Most people infected with Omicron weren't even...
# 556     Zoonotic Langya virus found in China, CDC says
# 557  CDC quietly removes 'claim' that spike protein...
# 558  9/11 vs. COVID: The Sorry Tale of a Nation Gon...
# 559  9/11, JFK, COVID, Holocaust…Will Americans Be ...
#
#                                                   link  article_type
# 0    https://www.consumerlab.com/reviews/quercetin-...             1
# 1    https://www.consumerlab.com/answers/how-and-wh...             1
# 2    https://www.consumerlab.com/recalls/14684/woma...             1
# 3    https://www.consumerlab.com/recalls/14683/sell...             1
# 4       https://www.consumerlab.com/topic/coronavirus/             1
# ..                                                 ...           ...
# 555  https://www.sott.net/article/471164-Most-peopl...             0
# 556  https://www.sott.net/article/470863-Zoonotic-L...             0
# 557  https://www.sott.net/article/471150-CDC-quietl...             0
# 558  https://www.veteranstoday.com/2022/08/12/9-11-...             0
# 559  https://www.veteranstoday.com/2022/08/20/911-j...             0
#
# [560 rows x 3 columns]

# %% [markdown]
# <h4>Scraping to Obtain the Textual Content in all Short-listed Articles</h4>

# %%
import numpy as np

# splitting the df into 30 different parts to improve async scraping efficiency
split_df = np.array_split(df, 30)

# %%
split_df[0]
# Out:
#                                                 title  \
# 0   \n \n \n Quercetin for Seasonal Allergies?\n \...
# 1   \n \n \n How Many Times Should You Test for CO...
# 2   \n 08/08/2022\n Woman Pleads Guilty for Sellin...
# 3   \n 08/08/2022\n Seller of CBD Warned for COVID...
# 4   \n \n Product Reviews and Answers to Questions...
# 5   \n \n Latest Reviews of N95, KN95 and Other Ma...
# 6                                         Coronavirus
# 7   \n Japanese Encephalitis in Australia\n C. Wal...
# 8   \n Case Series of Children with Acute Hepatiti...
# 9                        \n \n \n \n \n Coronavirus\n
# 10  Editorial Acute Hepatitis in Children in 2022 ...
# 11                                      \n COVID 19\n
# 12                       \n \n Coronavirus (COVID-19)
# 13  Reflections on Carrie Mae Weems\xe2\x80\x99s R...
# 14  COVID-19The essays here deliver fresh insights...
# 15  A Time Capsule of Creative Responses to the Pa...
# 16                             RESIST COVID | TAKE 6!
# 17                            Creativity During COVID
# 18  Did you follow COVID lockdown rules? Whether o...
#
#                                                  link  article_type
# 0   https://www.consumerlab.com/reviews/quercetin-...             1
# 1   https://www.consumerlab.com/answers/how-and-wh...             1
# 2   https://www.consumerlab.com/recalls/14684/woma...             1
# 3   https://www.consumerlab.com/recalls/14683/sell...             1
# 4      https://www.consumerlab.com/topic/coronavirus/             1
# 5   https://www.consumerlab.com/answers/how-to-mak...             1
# 6                        https://nejm.org/coronavirus             1
# 7   https://nejm.org/doi/full/10.1056/NEJMc2207004...             1
# 8   https://nejm.org/doi/full/10.1056/NEJMoa220629...             1
# 9                        https://nejm.org/coronavirus             1
# 10      https://nejm.orgdoi/full/10.1056/NEJMe2208409             1
# 11  https://www.aip.org/covid-impacts-on-physical-...             1
# 12  https://public.wmo.int/en/resources/coronaviru...             1
# 13  https://issues.org/resist-covid-take-6-carrie-...             1
# 14               https://issues.org/category/covid19/             1
# 15  https://issues.org/archive-of-creative-responses/             1
# 16  https://issues.org/resist-covid-take-6-carrie-...             1
# 17  https://issues.org/archive-of-creative-responses/             1
# 18  https://geneticliteracyproject.org/2022/08/22/...             1

# %%
from newspaper import Article
import time

# obtaining the texts for the articles present in the current chunk
def parse_chunk(articles: list) -> list:

    # creating a variable to store the article texts for the current chunk
    extracted_text = []

    # looping over all of the articles
    for article in articles:
        try:
            # attempting to obtain the article text for the current article
            current_article = Article(article[1])
            current_article.download(), current_article.parse()

            # adding the article text to storage
            extracted_text.append(current_article.text)
        except Exception:
            # adding in a sentinel value to storage to indicate failure
            extracted_text.append("N/A")

    return extracted_text

# %%
len(split_df)
# Out:
# 30

# %%
# creating a variable to store all the text for all of the articles
all_text = []

# %%
# loop over
for index, chunk in enumerate(split_df):
    # printing out a status message - specifying the current chunk number
    print(f'---- Chunk #{index+1} ----')

    # creating a variable to store the time execution is started
    start = time.time()

    # parsing the current chunk
    parsed_current_chunk = parse_chunk(chunk.values)

    # creating a variable to store the time execution is ended
    end = time.time()

    # printing out a status message - specifying the number of seconds elapsed
    print(end-start, "seconds elapsed")

    # adding all of the articles in the current chunk to storage
    all_text.append(parsed_current_chunk)
# Out:
# ---- Chunk #1 ----
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/isobarbaric/Desktop/Dev/Research/Science:Conspiracy Classifier/Fake-News-Classifier/Pipeline/data_processing.ipynb Cell 18 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/isobarbaric/Desktop/Dev/Research/Science%3AConspiracy%20Classifier/Fake-News-Classifier/Pipeline/data_processing.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> for index, chunk in enumerate(split_df):
#       <a href='vscode-notebook-cell:/Users/isobarbaric/Desktop/Dev/Research/Science%3AConspiracy%20Classifier/Fake-News-Classifier/Pipeline/data_processing.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a>     print(f'---- Chunk #{index+1} ----')
# ----> <a href='vscode-notebook-cell:/Users/isobarbaric/Desktop/Dev/Research/Science%3AConspiracy%20Classifier/Fake-News-Classifier/Pipeline/data_processing.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a>     parsed_current_chunk = parse_chunk(chunk.values)
#       <a href='vscode-notebook-cell:/Users/isobarbaric/Desktop/Dev/Research/Science%3AConspiracy%20Classifier/Fake-News-Classifier/Pipeline/data_processing.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a>     all_text.append(parsed_current_chunk)
#
# /Users/isobarbaric/Desktop/Dev/Research/Science:Conspiracy Classifier/Fake-News-Classifier/Pipeline/data_processing.ipynb Cell 18 in parse_chunk(articles)
#       <a href='vscode-notebook-cell:/Users/isobarbaric/Desktop/Dev/Research/Science%3AConspiracy%20Classifier/Fake-News-Classifier/Pipeline/data_processing.ipynb#X23sZmlsZQ%3D%3D?line=8'>9</a> try:
#      <a href='vscode-notebook-cell:/Users/isobarbaric/Desktop/Dev/Research/Science%3AConspiracy%20Classifier/Fake-News-Classifier/Pipeline/data_processing.ipynb#X23sZmlsZQ%3D%3D?line=9'>10</a>     current_article = Article(article[1])
# ---> <a href='vscode-notebook-cell:/Users/isobarbaric/Desktop/Dev/Research/Science%3AConspiracy%20Classifier/Fake-News-Classifier/Pipeline/data_processing.ipynb#X23sZmlsZQ%3D%3D?line=10'>11</a>     current_article.download(), current_article.parse()
#      <a href='vscode-notebook-cell:/Users/isobarbaric/Desktop/Dev/Research/Science%3AConspiracy%20Classifier/Fake-News-Classifier/Pipeline/data_processing.ipynb#X23sZmlsZQ%3D%3D?line=11'>12</a>     extracted_text.append(current_article.text)
#      <a href='vscode-notebook-cell:/Users/isobarbaric/Desktop/Dev/Research/Science%3AConspiracy%20Classifier/Fake-News-Classifier/Pipeline/data_processing.ipynb#X23sZmlsZQ%3D%3D?line=12'>13</a> except Exception:
#
# File ~/miniforge3/lib/python3.9/site-packages/newspaper/article.py:170, in Article.download(self, input_html, title, recursion_counter)
#     168 if input_html is None:
#     169     try:
# --> 170         html = network.get_html_2XX_only(self.url, self.config)
#     171     except requests.exceptions.RequestException as e:
#     172         self.download_state = ArticleDownloadState.FAILED_RESPONSE
#
# File ~/miniforge3/lib/python3.9/site-packages/newspaper/network.py:62, in get_html_2XX_only(url, config, response)
#      59 if response is not None:
#      60     return _get_html_from_response(response)
# ---> 62 response = requests.get(
#      63     url=url, **get_request_kwargs(timeout, useragent, proxies, headers))
#      65 html = _get_html_from_response(response)
#      67 if config.http_success_only:
#      68     # fail if HTTP sends a non 2XX response
#
# File ~/miniforge3/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniforge3/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniforge3/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/miniforge3/lib/python3.9/site-packages/requests/sessions.py:723, in Session.send(self, request, **kwargs)
#     720 if allow_redirects:
#     721     # Redirect resolving generator.
#     722     gen = self.resolve_redirects(r, request, **kwargs)
# --> 723     history = [resp for resp in gen]
#     724 else:
#     725     history = []
#
# File ~/miniforge3/lib/python3.9/site-packages/requests/sessions.py:723, in <listcomp>(.0)
#     720 if allow_redirects:
#     721     # Redirect resolving generator.
#     722     gen = self.resolve_redirects(r, request, **kwargs)
# --> 723     history = [resp for resp in gen]
#     724 else:
#     725     history = []
#
# File ~/miniforge3/lib/python3.9/site-packages/requests/sessions.py:266, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 266     resp = self.send(
#     267         req,
#     268         stream=stream,
#     269         timeout=timeout,
#     270         verify=verify,
#     271         cert=cert,
#     272         proxies=proxies,
#     273         allow_redirects=False,
#     274         **adapter_kwargs,
#     275     )
#     277     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     279     # extract redirect url, if any, for the next loop
#
# File ~/miniforge3/lib/python3.9/site-packages/requests/sessions.py:745, in Session.send(self, request, **kwargs)
#     742         pass
#     744 if not stream:
# --> 745     r.content
#     747 return r
#
# File ~/miniforge3/lib/python3.9/site-packages/requests/models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File ~/miniforge3/lib/python3.9/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/miniforge3/lib/python3.9/site-packages/urllib3/response.py:623, in HTTPResponse.stream(self, amt, decode_content)
#     607 """
#     608 A generator wrapper for the read() method. A call will block until
#     609 ``amt`` bytes have been read from the connection or until the
#    (...)
#     620     'content-encoding' header.
#     621 """
#     622 if self.chunked and self.supports_chunked_reads():
# --> 623     for line in self.read_chunked(amt, decode_content=decode_content):
#     624         yield line
#     625 else:
#
# File ~/miniforge3/lib/python3.9/site-packages/urllib3/response.py:815, in HTTPResponse.read_chunked(self, amt, decode_content)
#     812     return
#     814 while True:
# --> 815     self._update_chunk_length()
#     816     if self.chunk_left == 0:
#     817         break
#
# File ~/miniforge3/lib/python3.9/site-packages/urllib3/response.py:745, in HTTPResponse._update_chunk_length(self)
#     743 if self.chunk_left is not None:
#     744     return
# --> 745 line = self._fp.fp.readline()
#     746 line = line.split(b";", 1)[0]
#     747 try:
#
# File ~/miniforge3/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~/miniforge3/lib/python3.9/ssl.py:1242, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238     if flags != 0:
#    1239         raise ValueError(
#    1240           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241           self.__class__)
# -> 1242     return self.read(nbytes, buffer)
#    1243 else:
#    1244     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniforge3/lib/python3.9/ssl.py:1100, in SSLSocket.read(self, len, buffer)
#    1098 try:
#    1099     if buffer is not None:
# -> 1100         return self._sslobj.read(len, buffer)
#    1101     else:
#    1102         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
df.shape
# Out:
# (560, 3)

# %%
# ensuring no extra columns have been created by any account
assert sum(len(elem) for elem in all_text) == df.shape[0]

# %%
df
# Out:
#                                                  title  \
# 0    \n \n \n Quercetin for Seasonal Allergies?\n \...
# 1    \n \n \n How Many Times Should You Test for CO...
# 2    \n 08/08/2022\n Woman Pleads Guilty for Sellin...
# 3    \n 08/08/2022\n Seller of CBD Warned for COVID...
# 4    \n \n Product Reviews and Answers to Questions...
# ..                                                 ...
# 555  Most people infected with Omicron weren't even...
# 556     Zoonotic Langya virus found in China, CDC says
# 557  CDC quietly removes 'claim' that spike protein...
# 558  9/11 vs. COVID: The Sorry Tale of a Nation Gon...
# 559  9/11, JFK, COVID, Holocaust…Will Americans Be ...
#
#                                                   link  article_type
# 0    https://www.consumerlab.com/reviews/quercetin-...             1
# 1    https://www.consumerlab.com/answers/how-and-wh...             1
# 2    https://www.consumerlab.com/recalls/14684/woma...             1
# 3    https://www.consumerlab.com/recalls/14683/sell...             1
# 4       https://www.consumerlab.com/topic/coronavirus/             1
# ..                                                 ...           ...
# 555  https://www.sott.net/article/471164-Most-peopl...             0
# 556  https://www.sott.net/article/470863-Zoonotic-L...             0
# 557  https://www.sott.net/article/471150-CDC-quietl...             0
# 558  https://www.veteranstoday.com/2022/08/12/9-11-...             0
# 559  https://www.veteranstoday.com/2022/08/20/911-j...             0
#
# [560 rows x 3 columns]

# %%
# creating a new column to store the texts for a particular article
df['text'] = 'undetermined'

# moving the article_type column to the far end of the dataframe, as where it should be
df.insert(len(df.columns)-1, 'article_type', df.pop('article_type'))

# %%
# creating a variable to store the current index in the all_text list
current_index = 0

# looping over all of the articles
for current_chunk in all_text:

    # looping over the articles parsed in the current chunk
    for current_text in current_chunk:

        # replacing the value in the current row with current_text
        df.at[current_index, 'text'] = current_text

        # incrementing the current_index
        current_index += 1

# %%
df
# Out:
#                                                  title  \
# 0    \n \n \n Quercetin for Seasonal Allergies?\n \...
# 1    \n \n \n How Many Times Should You Test for CO...
# 2    \n 08/08/2022\n Woman Pleads Guilty for Sellin...
# 3    \n 08/08/2022\n Seller of CBD Warned for COVID...
# 4    \n \n Product Reviews and Answers to Questions...
# ..                                                 ...
# 555  Most people infected with Omicron weren't even...
# 556     Zoonotic Langya virus found in China, CDC says
# 557  CDC quietly removes 'claim' that spike protein...
# 558  9/11 vs. COVID: The Sorry Tale of a Nation Gon...
# 559  9/11, JFK, COVID, Holocaust…Will Americans Be ...
#
#                                                   link  article_type
# 0    https://www.consumerlab.com/reviews/quercetin-...             1
# 1    https://www.consumerlab.com/answers/how-and-wh...             1
# 2    https://www.consumerlab.com/recalls/14684/woma...             1
# 3    https://www.consumerlab.com/recalls/14683/sell...             1
# 4       https://www.consumerlab.com/topic/coronavirus/             1
# ..                                                 ...           ...
# 555  https://www.sott.net/article/471164-Most-peopl...             0
# 556  https://www.sott.net/article/470863-Zoonotic-L...             0
# 557  https://www.sott.net/article/471150-CDC-quietl...             0
# 558  https://www.veteranstoday.com/2022/08/12/9-11-...             0
# 559  https://www.veteranstoday.com/2022/08/20/911-j...             0
#
# [560 rows x 3 columns]

# %%
# print out how many invalid articles there are
df['text'].value_counts()['N/A']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'text'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/isobarbaric/Desktop/Dev/Research/Science:Conspiracy Classifier/Fake-News-Classifier/Pipeline/data_processing.ipynb Cell 26 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/isobarbaric/Desktop/Dev/Research/Science%3AConspiracy%20Classifier/Fake-News-Classifier/Pipeline/data_processing.ipynb#X65sZmlsZQ%3D%3D?line=0'>1</a> # print out how many invalid articles there are
# ----> <a href='vscode-notebook-cell:/Users/isobarbaric/Desktop/Dev/Research/Science%3AConspiracy%20Classifier/Fake-News-Classifier/Pipeline/data_processing.ipynb#X65sZmlsZQ%3D%3D?line=1'>2</a> df['text'].value_counts()['N/A']
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/miniforge3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'text'

# %%
# drop all columns with N/A in their text column
df = df[df['text'] != "N/A"]

# %%
df
# Out:
#                                                  title  \
# 0    \n \n \n Quercetin for Seasonal Allergies?\n \...
# 1    \n \n \n How Many Times Should You Test for CO...
# 2    \n 08/08/2022\n Woman Pleads Guilty for Sellin...
# 3    \n 08/08/2022\n Seller of CBD Warned for COVID...
# 4    \n \n Product Reviews and Answers to Questions...
# ..                                                 ...
# 555  Most people infected with Omicron weren't even...
# 556     Zoonotic Langya virus found in China, CDC says
# 557  CDC quietly removes 'claim' that spike protein...
# 558  9/11 vs. COVID: The Sorry Tale of a Nation Gon...
# 559  9/11, JFK, COVID, Holocaust…Will Americans Be ...
#
#                                                   link  \
# 0    https://www.consumerlab.com/reviews/quercetin-...
# 1    https://www.consumerlab.com/answers/how-and-wh...
# 2    https://www.consumerlab.com/recalls/14684/woma...
# 3    https://www.consumerlab.com/recalls/14683/sell...
# 4       https://www.consumerlab.com/topic/coronavirus/
# ..                                                 ...
# 555  https://www.sott.net/article/471164-Most-peopl...
# 556  https://www.sott.net/article/470863-Zoonotic-L...
# 557  https://www.sott.net/article/471150-CDC-quietl...
# 558  https://www.veteranstoday.com/2022/08/12/9-11-...
# 559  https://www.veteranstoday.com/2022/08/20/911-j...
#
#                                                   text  article_type
# 0    Save to favorites\n\nThis feature is restricte...             1
# 1    Answer:\n\nBefore we get into specifics, let's...             1
# 2    On July 27, 2022, Diana Daffin, owner of Savvy...             1
# 3    On August 4, 2022, the FDA sent a warning lett...             1
# 4    Save to favorites\n\nThis feature is restricte...             1
# ..                                                 ...           ...
# 555  The lack of public awareness about being infec...             0
# 556  © Daily PRABHAT/simplifay\n\n\n\nThe 26 patien...             0
# 557  The mRNA vaccines cannot give you COVID-19. Th...             0
# 558  By John Kaminski\n\nWhat goes around comes aro...             0
# 559  List of stories\n\nE. Michael Jones joined me ...             0
#
# [480 rows x 4 columns]

# %% [markdown]
# <h4>Cleaning the Data Obtained to Ensure <i>Only</i> Textual Content is Taken</h4>

# %% [markdown]
# - remove all escape sequences and non-ascii unicode characters (like \\xe2)
# - .strip() to remove any unnecessary spaces
# - standardize to single space between word

# %%
import re

# remove escape characters (\n works, unicode characters stuff like \\xe90 doesn't work the best - e.g. the latter part of possessive or contractions are cut off)
def clean_str(unfiltered_str: str):
    formatted_str = re.sub('\\\\\w+', '', unfiltered_str).strip()
    return str((' ').join(formatted_str.split()))

# %%
# loop over all of the columns and and replace existing contents with cleaned up contents
for i, row in df.iterrows():
    df.at[i, 'title'] = clean_str(df.at[i, 'title'])
    df.at[i, 'text'] = clean_str(df.at[i, 'text'])

# %%
df
# Out:
#                                                  title  \
# 0    Quercetin for Seasonal Allergies? A recent stu...
# 1    How Many Times Should You Test for COVID? It m...
# 2    08/08/2022 Woman Pleads Guilty for Selling and...
# 3    08/08/2022 Seller of CBD Warned for COVID-19 C...
# 4    Product Reviews and Answers to Questions About...
# ..                                                 ...
# 555  Most people infected with Omicron weren't even...
# 556     Zoonotic Langya virus found in China, CDC says
# 557  CDC quietly removes 'claim' that spike protein...
# 558  9/11 vs. COVID: The Sorry Tale of a Nation Gon...
# 559  9/11, JFK, COVID, Holocaust…Will Americans Be ...
#
#                                                   link  \
# 0    https://www.consumerlab.com/reviews/quercetin-...
# 1    https://www.consumerlab.com/answers/how-and-wh...
# 2    https://www.consumerlab.com/recalls/14684/woma...
# 3    https://www.consumerlab.com/recalls/14683/sell...
# 4       https://www.consumerlab.com/topic/coronavirus/
# ..                                                 ...
# 555  https://www.sott.net/article/471164-Most-peopl...
# 556  https://www.sott.net/article/470863-Zoonotic-L...
# 557  https://www.sott.net/article/471150-CDC-quietl...
# 558  https://www.veteranstoday.com/2022/08/12/9-11-...
# 559  https://www.veteranstoday.com/2022/08/20/911-j...
#
#                                                   text  article_type
# 0    Save to favorites This feature is restricted t...             1
# 1    Answer: Before we get into specifics, let's st...             1
# 2    On July 27, 2022, Diana Daffin, owner of Savvy...             1
# 3    On August 4, 2022, the FDA sent a warning lett...             1
# 4    Save to favorites This feature is restricted t...             1
# ..                                                 ...           ...
# 555  The lack of public awareness about being infec...             0
# 556  © Daily PRABHAT/simplifay The 26 patients deve...             0
# 557  The mRNA vaccines cannot give you COVID-19. Th...             0
# 558  By John Kaminski What goes around comes around...             0
# 559  List of stories E. Michael Jones joined me on ...             0
#
# [480 rows x 4 columns]

# %% [markdown]
# <h4>Saving the DataFrame for Short-listed Articles as JSON</h4>

# %%
# saving the dataframe under the 'Data' directory for further use

processed_json = df.to_json('Data/processed/processed_data.json', orient='records', indent=4)
