# %%
import pandas as pd

# %%
a = pd.read_pickle('../Data/processed/processed_data.pkl')

# %%
a
# Out:
#                                                  title  \
# 0    \n \n \n Quercetin for Seasonal Allergies?\n \...
# 1    \n \n \n Don't Throw Out Expired COVID Tests\n...
# 2    \n 08/08/2022\n Woman Pleads Guilty for Sellin...
# 3    \n \n Latest Reviews of N95, KN95 and Other Ma...
# 4    \n \n Product Reviews and Answers to Questions...
# ..                                                 ...
# 616  CDC Caught Deleting 6,000 COVID Vaccine Deaths...
# 617  Blockbuster: It wasn’t Wuhan, despite Rand Pau...
# 618  How Much Does the US Owe in Reparations for th...
# 619      \nWarnings of a Catastrophic COVID Autumn\n\n
# 621  Army Commander Mandates Masks Indoors Again ov...
#
#                                                   link  \
# 0    https://www.consumerlab.com/reviews/quercetin-...
# 1    https://www.consumerlab.com/answers/how-and-wh...
# 2    https://www.consumerlab.com/recalls/14684/woma...
# 3    https://www.consumerlab.com/answers/how-to-mak...
# ...
