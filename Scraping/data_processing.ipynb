# %%
science_url = 'https://mediabiasfactcheck.com/pro-science/'
conspiracy_url = 'https://mediabiasfactcheck.com/conspiracy/'

# %%
from article_finder import ArticleFinder
article_compiler = ArticleFinder()

# %%
import json
def write_to_storage(name: str, articles: list[str]):
    filename = "../Data/" + name + ".json" 
    with open(filename, 'w') as storage:
        storage.write(json.dumps(articles, indent = 4))

# %%
science_articles = article_compiler.find_articles(science_url)
# Out:
# total dysfunctional: 0; total attempts: 313

# %%
write_to_storage('science', science_articles)

# %%
conspiracy_articles = article_compiler.find_articles(conspiracy_url)
# Out:
# total dysfunctional: 0; total attempts: 488

# %%
write_to_storage('conspiracy', conspiracy_articles)

# %%
min_len = min(len(science_articles), len(conspiracy_articles))
science_articles = science_articles[:min_len]
conspiracy_articles = conspiracy_articles[:min_len]

# %%
import pandas as pd
import numpy as np

# %%
df_science = pd.DataFrame.from_dict(science_articles)
df_conspiracy = pd.DataFrame.from_dict(conspiracy_articles)

# %%
df_science['article_type'] = 1
df_conspiracy['article_type'] = 0

# %%
df_science
# Out:
#                                                  title  \
# 0    \n 08/05/2022\n Vitamin C or Melatonin for COV...
# 1    \n \n Product Reviews and Answers to Questions...
# 2    \n \n Latest Reviews of N95, KN95 and Other Ma...
# 3                    \n 08/05/2022\n GABA for COVID?\n
# 4    \n \n \n Quercetin for Seasonal Allergies?\n \...
# ..                                                 ...
# 308  \xe2\x80\x9cDowngrade your mask before enterin...
# 309  Effectiveness of public health measures in red...
# 310                                  COVID Information
# 311  RESEARCH TOPICS \n 20 Jul 2022\n Heat wave: ar...
# 312  RESEARCH TOPICS \n 20 Jul 2022\n Heat wave: ar...
#
#                                                   link     text  article_type
# 0    https://www.consumerlab.com/clinical-updates/#...  testing             1
# 1       https://www.consumerlab.com/topic/coronavirus/  testing             1
# 2    https://www.consumerlab.com/answers/how-to-mak...  testing             1
# 3    https://www.consumerlab.com/clinical-updates/#...  testing             1
# 4    https://www.consumerlab.com/reviews/quercetin-...  testing             1
# ..                                                 ...      ...           ...
# 308          https://www.bmj.com/content/378/bmj.o1929  testing             1
# 309            https://doi.org/10.1136/bmj-2021-068302  testing             1
# 310            https://www.sciencehistory.org/covid-19  testing             1
# 311  https://blog.frontiersin.org/2022/07/20/heat-w...  testing             1
# 312  https://blog.frontiersin.org/2022/07/20/heat-w...  testing             1
#
# [313 rows x 4 columns]

# %%
df_conspiracy
# Out:
#                                                  title  \
# 0    \n\t\t\t\t\t\t\t\t\t\t‘Situation is Really Pre...
# 1    \n\t\t\t\t\t\t\n \t[ August 6, 2022 ] \n\t\t\t...
# 2    \n\t\t\t\t\t\t\t\t\t\tTHE PLAN – WHO plans for...
# 3    \n\t\t\t\t\t\t\t\t\t\t‘Situation is Really Pre...
# 4    \n\t\t\tSpanish Invaders Were Not the Cause of...
# ..                                                 ...
# 308  Study finds that forced business closures duri...
# 309  COVID-19 vaccines more dangerous to children t...
# 310  Hundreds of Coast Guard members sue Biden regi...
# 311  Scientists with ties to Bill Gates and Anthony...
# 312  Spain sprays lethal CHEMTRAILS on its populati...
#
#                                                   link     text  article_type
# 0    https://www.winterwatch.net/2022/08/situation-...  testing             0
# 1    https://www.winterwatch.net/2022/08/situation-...  testing             0
# 2    https://www.winterwatch.net/2022/07/the-plan-w...  testing             0
# 3    https://www.winterwatch.net/2022/08/situation-...  testing             0
# 4    https://www.winterwatch.net/2022/06/spanish-in...  testing             0
# ..                                                 ...      ...           ...
# 308  https://www.medicine.news2022-08-05-forced-bus...  testing             0
# 309  https://www.medicine.news2022-08-01-vaccines-m...  testing             0
# 310  https://www.medicine.news2022-08-04-coast-guar...  testing             0
# 311  https://www.medicine.news2022-08-04-gates-fauc...  testing             0
# 312  https://www.medicine.news2022-08-07-spain-spra...  testing             0
#
# [313 rows x 4 columns]

# %%
# merge the two dataframes
df = pd.concat([df_science, df_conspiracy], axis=0, ignore_index=True)

# %%
df
# Out:
#                                                  title  \
# 0    \n 08/05/2022\n Vitamin C or Melatonin for COV...
# 1    \n \n Product Reviews and Answers to Questions...
# 2    \n \n Latest Reviews of N95, KN95 and Other Ma...
# 3                    \n 08/05/2022\n GABA for COVID?\n
# 4    \n \n \n Quercetin for Seasonal Allergies?\n \...
# ..                                                 ...
# 621  Study finds that forced business closures duri...
# 622  COVID-19 vaccines more dangerous to children t...
# 623  Hundreds of Coast Guard members sue Biden regi...
# 624  Scientists with ties to Bill Gates and Anthony...
# 625  Spain sprays lethal CHEMTRAILS on its populati...
#
#                                                   link     text  article_type
# 0    https://www.consumerlab.com/clinical-updates/#...  testing             1
# 1       https://www.consumerlab.com/topic/coronavirus/  testing             1
# 2    https://www.consumerlab.com/answers/how-to-mak...  testing             1
# 3    https://www.consumerlab.com/clinical-updates/#...  testing             1
# 4    https://www.consumerlab.com/reviews/quercetin-...  testing             1
# ..                                                 ...      ...           ...
# 621  https://www.medicine.news2022-08-05-forced-bus...  testing             0
# 622  https://www.medicine.news2022-08-01-vaccines-m...  testing             0
# 623  https://www.medicine.news2022-08-04-coast-guar...  testing             0
# 624  https://www.medicine.news2022-08-04-gates-fauc...  testing             0
# 625  https://www.medicine.news2022-08-07-spain-spra...  testing             0
#
# [626 rows x 4 columns]

# %%
split_df = np.array_split(df, 30)

# %%
split_df[0]
# Out:
#                                                 title  \
# 0   \n 08/05/2022\n Vitamin C or Melatonin for COV...
# 1   \n \n Product Reviews and Answers to Questions...
# 2   \n \n Latest Reviews of N95, KN95 and Other Ma...
# 3                   \n 08/05/2022\n GABA for COVID?\n
# 4   \n \n \n Quercetin for Seasonal Allergies?\n \...
# 5   \n \n \n Don't Throw Out Expired COVID Tests\n...
# 6   \n 08/08/2022\n Seller of CBD Warned for COVID...
# 7      \n 08/05/2022\n Do Eyeglasses prevent COVID?\n
# 8   \n A Zoonotic Henipavirus in China\n X.-A. Zha...
# 9   \n A Zoonotic Henipavirus in Febrile Patients ...
# 10  \n More Than a Little Unsteady\n A.W. Kraft an...
# 11  \n In Vitro Activity of Antibodies and Drugs a...
# 12                                        Coronavirus
# 13                       \n \n \n \n \n Coronavirus\n
# 14  \n Efficacy of Antibodies and Antiviral Drugs ...
# 15  RESEARCH TOPICS \n 20 Jul 2022\n Heat wave: ar...
# 16  RESEARCH TOPICS \n 20 Jul 2022\n Heat wave: ar...
# 17                                      \n COVID 19\n
# 18                       \n \n Coronavirus (COVID-19)
# 19                            Creativity During COVID
# 20  A Time Capsule of Creative Responses to the Pa...
#
#                                                  link     text  article_type
# 0   https://www.consumerlab.com/clinical-updates/#...  testing             1
# 1      https://www.consumerlab.com/topic/coronavirus/  testing             1
# 2   https://www.consumerlab.com/answers/how-to-mak...  testing             1
# 3   https://www.consumerlab.com/clinical-updates/#...  testing             1
# 4   https://www.consumerlab.com/reviews/quercetin-...  testing             1
# 5   https://www.consumerlab.com/answers/how-and-wh...  testing             1
# 6   https://www.consumerlab.com/recalls/14683/sell...  testing             1
# 7   https://www.consumerlab.com/clinical-updates/#...  testing             1
# 8   https://nejm.org/doi/full/10.1056/NEJMc2202705...  testing             1
# 9   https://nejm.org/doi/full/10.1056/NEJMc2202705...  testing             1
# 10  https://nejm.org/doi/full/10.1056/NEJMimc21174...  testing             1
# 11  https://nejm.org/doi/full/10.1056/NEJMc2207519...  testing             1
# 12                       https://nejm.org/coronavirus  testing             1
# 13                       https://nejm.org/coronavirus  testing             1
# 14  https://nejm.org/doi/full/10.1056/NEJMc2207519...  testing             1
# 15  https://blog.frontiersin.org/2022/07/20/heat-w...  testing             1
# 16  https://blog.frontiersin.org/2022/07/20/heat-w...  testing             1
# 17  https://www.aip.org/covid-impacts-on-physical-...  testing             1
# 18  https://public.wmo.int/en/resources/coronaviru...  testing             1
# 19  https://issues.org/archive-of-creative-responses/  testing             1
# 20  https://issues.org/archive-of-creative-responses/  testing             1

# %%
from newspaper import Article
import time

# %%
def parse_chunk(articles):
    start = time.time()
    extracted_text = []
    for article in articles:
        print("parsing:", article[1])
        current_article = Article(article[1])
        current_article.download(), current_article.parse()
        extracted_text.append(current_article.text)
        end = time.time()  
    print(end-start, "seconds elapsed")
    return extracted_text

# %%
len(split_df)
# Out:
# 30

# %%
parse_chunk(split_df[2].values)
# Out:
# https://www.popsci.com/health/children-danger-heat-waves/
# https://www.mentaldaily.com/article/2022/08/covid-19-may-be-linked-to-an-increase-in-brain-infections-in-children
# https://www.mentaldaily.com/article/2022/07/how-herpes-simplex-virus-may-help-trigger-the-onset-of-alzheimers-disease
# https://www.seeker.com/videos/health/this-is-how-your-body-builds-immunity
# https://skepticalscience.com\'104-left-heat-england.html\'
# ---------------------------------------------------------------------------
# ArticleException                          Traceback (most recent call last)
# /Users/isobarbaric/Desktop/Dev/Projects/Fake-News-Classifier/Scraping/preprocessing.ipynb Cell 21 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/isobarbaric/Desktop/Dev/Projects/Fake-News-Classifier/Scraping/preprocessing.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> parse_chunk(split_df[2].values)
#
# /Users/isobarbaric/Desktop/Dev/Projects/Fake-News-Classifier/Scraping/preprocessing.ipynb Cell 21 in parse_chunk(articles)
#       <a href='vscode-notebook-cell:/Users/isobarbaric/Desktop/Dev/Projects/Fake-News-Classifier/Scraping/preprocessing.ipynb#X35sZmlsZQ%3D%3D?line=4'>5</a>     print(article[1])
#       <a href='vscode-notebook-cell:/Users/isobarbaric/Desktop/Dev/Projects/Fake-News-Classifier/Scraping/preprocessing.ipynb#X35sZmlsZQ%3D%3D?line=5'>6</a>     current_article = Article(article[1])
# ----> <a href='vscode-notebook-cell:/Users/isobarbaric/Desktop/Dev/Projects/Fake-News-Classifier/Scraping/preprocessing.ipynb#X35sZmlsZQ%3D%3D?line=6'>7</a>     current_article.download(), current_article.parse()
#       <a href='vscode-notebook-cell:/Users/isobarbaric/Desktop/Dev/Projects/Fake-News-Classifier/Scraping/preprocessing.ipynb#X35sZmlsZQ%3D%3D?line=7'>8</a>     extracted_text.append(current_article.text)
#       <a href='vscode-notebook-cell:/Users/isobarbaric/Desktop/Dev/Projects/Fake-News-Classifier/Scraping/preprocessing.ipynb#X35sZmlsZQ%3D%3D?line=8'>9</a> end = time.time()
#
# File ~/miniforge3/lib/python3.9/site-packages/newspaper/article.py:191, in Article.parse(self)
#     190 def parse(self):
# --> 191     self.throw_if_not_downloaded_verbose()
#     193     self.doc = self.config.get_parser().fromstring(self.html)
#     194     self.clean_doc = copy.deepcopy(self.doc)
#
# File ~/miniforge3/lib/python3.9/site-packages/newspaper/article.py:531, in Article.throw_if_not_downloaded_verbose(self)
#     529     raise ArticleException('You must `download()` an article first!')
#     530 elif self.download_state == ArticleDownloadState.FAILED_RESPONSE:
# --> 531     raise ArticleException('Article `download()` failed with %s on URL %s' %
#     532           (self.download_exception_msg, self.url))
#
# ArticleException: Article `download()` failed with 404 Client Error: Not Found for url: https://skepticalscience.com/%5C'104-left-heat-england.html%5C' on URL https://skepticalscience.com\'104-left-heat-england.html\'

# %%
# not as urgent: remove all escape characters from titles using escape_seq 
escape_seq = ''.join([chr(char) for char in range(1, 32)])
